# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

def train_and_optimize_DBSCAN(data, feature_cols, eps_min=0.1, eps_max=1.0, eps_step=0.1, min_samples_min=2, min_samples_max=10, min_samples_step=1):
    """
    --------------------------------------------------------------------------
    Trains and optimizes DBSCAN on a given dataset.
    -----------------------------------------------------------------------------
    
    Parameters:
    ----------------------------------------------------------------------------
        - data (pandas.DataFrame): 
            The dataset to be used for training and optimization.
        - feature_cols (list): 
            A list of column names for the features to be used for training.
        - eps_min (float): 
            The minimum value of the eps parameter to try during optimization. Default is 0.1.
        - eps_max (float): 
            The maximum value of the eps parameter to try during optimization. Default is 1.0.
        - eps_step (float): 
            The step size for the eps parameter during optimization. Default is 0.1.
        - min_samples_min (int): 
            The minimum value of the min_samples parameter to try during optimization. Default is 2.
        - min_samples_max (int): 
            The maximum value of the min_samples parameter to try during optimization. Default is 10.
        - min_samples_step (int):
            The step size for the min_samples parameter during optimization. Default is 1.
    -----------------------------------------------------------------------------------
    Returns:
    -----------------------------------------------------------------------------------
        A tuple of the optimal values for eps and min_samples, 
        as determined by the silhouette score.
    -------------------------------------------------------------------------------
    """
    
    # Select the feature columns
    X = data[feature_cols].values
    
    # Normalize the data
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    # Try different values of eps and min_samples and evaluate them
    scores = []
    for eps in np.arange(eps_min, eps_max + eps_step, eps_step):
        for min_samples in range(min_samples_min, min_samples_max + min_samples_step, min_samples_step):
            dbscan = DBSCAN(eps=eps, min_samples=min_samples)
            dbscan.fit(X)
            if len(set(dbscan.labels_)) > 1:  # Skip if only one cluster is found
                score = silhouette_score(X, dbscan.labels_)
                scores.append((eps, min_samples, score))
                print("DBSCAN with eps={}, min_samples={} - Silhouette Score: {}".format(eps, min_samples, score))
    
    # Find the optimal values for eps and min_samples
    if len(scores) > 0:
        optimal_eps, optimal_min_samples, _ = max(scores, key=lambda x: x[2])
        print("Optimal values - eps: {}, min_samples: {}".format(optimal_eps, optimal_min_samples))
        return (optimal_eps, optimal_min_samples)
    else:
        print("Could not find optimal values.")
        return None

    
#Example of application
np.random.seed(123)
data = pd.DataFrame({
    'feature1': np.random.randn(100),
    'feature2': np.random.randn(100),
    'feature3': np.random.randn(100)
})

optimal_params = train_and_optimize_DBSCAN(data, ['feature1', 'feature2', 'feature3'])
# Out:
# DBSCAN with eps=0.2, min_samples=2 - Silhouette Score: -0.24534006907889722
# DBSCAN with eps=0.30000000000000004, min_samples=2 - Silhouette Score: -0.3666549436628062
# DBSCAN with eps=0.4, min_samples=2 - Silhouette Score: -0.19255392708005956
# DBSCAN with eps=0.4, min_samples=3 - Silhouette Score: -0.2927350459462999
# DBSCAN with eps=0.4, min_samples=4 - Silhouette Score: -0.20248209056625605
# DBSCAN with eps=0.5, min_samples=2 - Silhouette Score: -0.1039565957711876
# DBSCAN with eps=0.5, min_samples=3 - Silhouette Score: -0.14434355312216604
# DBSCAN with eps=0.5, min_samples=4 - Silhouette Score: -0.250135046082652
# DBSCAN with eps=0.5, min_samples=5 - Silhouette Score: -0.17626965082518287
# DBSCAN with eps=0.6, min_samples=2 - Silhouette Score: -0.028587839573766892
# DBSCAN with eps=0.6, min_samples=3 - Silhouette Score: -0.04549309359472091
# DBSCAN with eps=0.6, min_samples=4 - Silhouette Score: -0.13205481210273276
# DBSCAN with eps=0.6, min_samples=5 - Silhouette Score: -0.18247856175160082
# DBSCAN with eps=0.6, min_samples=6 - Silhouette Score: -0.1763767115479867
# DBSCAN with eps=0.6, min_samples=7 - Silhouette Score: -0.1902102922849266
# DBSCAN with eps=0.7000000000000001, min_samples=2 - Silhouette Score: -0.024952711177169806
# DBSCAN with eps=0.7000000000000001, min_samples=3 - Silhouette Score: 0.02171573313932576
# DBSCAN with eps=0.7000000000000001, min_samples=4 - Silhouette Score: 0.010208659957814947
# DBSCAN with eps=0.7000000000000001, min_samples=5 - Silhouette Score: -0.17504412100137487
# DBSCAN with eps=0.7000000000000001, min_samples=6 - Silhouette Score: -0.104828287588778
# DBSCAN with eps=0.7000000000000001, min_samples=7 - Silhouette Score: -0.13319118811692857
# DBSCAN with eps=0.7000000000000001, min_samples=8 - Silhouette Score: -0.23536521712992114
# DBSCAN with eps=0.8, min_samples=2 - Silhouette Score: 0.058460971462482594
# DBSCAN with eps=0.8, min_samples=3 - Silhouette Score: 0.058460971462482594
# DBSCAN with eps=0.8, min_samples=4 - Silhouette Score: 0.05629971612620637
# DBSCAN with eps=0.8, min_samples=5 - Silhouette Score: 0.15857293433522845
# DBSCAN with eps=0.8, min_samples=6 - Silhouette Score: 0.13505613673803687
# DBSCAN with eps=0.8, min_samples=7 - Silhouette Score: 0.12160832034602316
# DBSCAN with eps=0.8, min_samples=8 - Silhouette Score: 0.04602616074272854
# DBSCAN with eps=0.8, min_samples=9 - Silhouette Score: -0.006675958008981064
# DBSCAN with eps=0.8, min_samples=10 - Silhouette Score: -0.035142646539200406
# DBSCAN with eps=0.9, min_samples=2 - Silhouette Score: 0.1431168739064587
# DBSCAN with eps=0.9, min_samples=3 - Silhouette Score: 0.24960863974637718
# DBSCAN with eps=0.9, min_samples=4 - Silhouette Score: 0.246806982840983
# DBSCAN with eps=0.9, min_samples=5 - Silhouette Score: 0.246806982840983
# DBSCAN with eps=0.9, min_samples=6 - Silhouette Score: 0.19062937114725628
# DBSCAN with eps=0.9, min_samples=7 - Silhouette Score: 0.1827051786357924
# DBSCAN with eps=0.9, min_samples=8 - Silhouette Score: 0.17732347253818584
# DBSCAN with eps=0.9, min_samples=9 - Silhouette Score: 0.14791404996766752
# DBSCAN with eps=0.9, min_samples=10 - Silhouette Score: 0.1275031572816179
# DBSCAN with eps=1.0, min_samples=2 - Silhouette Score: 0.19062968720178783
# DBSCAN with eps=1.0, min_samples=3 - Silhouette Score: 0.19062968720178783
# DBSCAN with eps=1.0, min_samples=4 - Silhouette Score: 0.27128133853620945
# DBSCAN with eps=1.0, min_samples=5 - Silhouette Score: 0.27004729892372115
# DBSCAN with eps=1.0, min_samples=6 - Silhouette Score: 0.26166497588258586
# DBSCAN with eps=1.0, min_samples=7 - Silhouette Score: 0.21498988922654033
# DBSCAN with eps=1.0, min_samples=8 - Silhouette Score: 0.2065404446653208
# DBSCAN with eps=1.0, min_samples=9 - Silhouette Score: 0.2065404446653208
# DBSCAN with eps=1.0, min_samples=10 - Silhouette Score: 0.19048230431606844
# Optimal values - eps: 1.0, min_samples: 4
